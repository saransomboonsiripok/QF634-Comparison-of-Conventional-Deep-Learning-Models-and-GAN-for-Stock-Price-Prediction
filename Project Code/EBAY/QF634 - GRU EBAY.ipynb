# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from numpy import *
from math import sqrt
from pandas import *
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Bidirectional
from tensorflow.keras.layers import BatchNormalization, Embedding, TimeDistributed, LeakyReLU
from tensorflow.keras.layers import GRU, LSTM
from tensorflow.keras.optimizers import Adam
from matplotlib import pyplot
from pickle import load

# Load data
X_train = np.load("X_train.npy", allow_pickle=True)
y_train = np.load("y_train.npy", allow_pickle=True)
X_test = np.load("X_test.npy", allow_pickle=True)
y_test = np.load("y_test.npy", allow_pickle=True)
yc_train = np.load("yc_train.npy", allow_pickle=True)
yc_test = np.load("yc_test.npy", allow_pickle=True)

# Parameters
LR = 0.0001
BATCH_SIZE = 128
N_EPOCH = 164

input_dim = X_train.shape[1]
feature_size = X_train.shape[2]
output_dim = y_train.shape[1]


def basic_GRU(input_dim, output_dim, feature_size) -> tf.keras.models.Model:
    model = Sequential()
    model.add(GRU(units=128, return_sequences = True, input_shape=(input_dim, feature_size)))  # 256, return_sequences = True
    # model.add(GRU(units=256, recurrent_dropout = 0.2)) #, return_sequences = True
    model.add(GRU(units=64, input_shape=(input_dim, feature_size)))
    #model.add(Dense(128))
    model.add(Dense(32))
    # model.add(Dense(32))
    model.add(Dense(units=output_dim))
    model.compile(optimizer=Adam(lr=LR), loss='mse')
    history = model.fit(X_train, y_train, epochs=N_EPOCH, batch_size=BATCH_SIZE, validation_data=(X_test, y_test),
                        verbose=2, shuffle=False)

    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='validation')
    pyplot.legend()
    pyplot.show()

    return model


model = basic_GRU(input_dim, output_dim, feature_size)
print(model.summary())
model.save('GRU_30to3.h5')

yhat = model.predict(X_test, verbose=0)
# print(yhat)

rmse = sqrt(mean_squared_error(y_test, yhat))
print(rmse)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/164
# 14/14 - 1s - loss: 0.2626 - val_loss: 0.0226 - 1s/epoch - 107ms/step
# Epoch 2/164
# 14/14 - 0s - loss: 0.2723 - val_loss: 0.2869 - 60ms/epoch - 4ms/step
# Epoch 3/164
# 14/14 - 0s - loss: 0.0219 - val_loss: 0.4475 - 70ms/epoch - 5ms/step
# Epoch 4/164
# 14/14 - 0s - loss: 0.0075 - val_loss: 0.2625 - 79ms/epoch - 6ms/step
# Epoch 5/164
# 14/14 - 0s - loss: 0.0033 - val_loss: 0.1893 - 80ms/epoch - 6ms/step
# Epoch 6/164
# 14/14 - 0s - loss: 0.0027 - val_loss: 0.1650 - 113ms/epoch - 8ms/step
# Epoch 7/164
# 14/14 - 0s - loss: 0.0011 - val_loss: 0.1636 - 77ms/epoch - 5ms/step
# Epoch 8/164
# 14/14 - 0s - loss: 0.0012 - val_loss: 0.1545 - 79ms/epoch - 6ms/step
# Epoch 9/164
# 14/14 - 0s - loss: 8.9229e-04 - val_loss: 0.1417 - 77ms/epoch - 6ms/step
# Epoch 10/164
# 14/14 - 0s - loss: 8.7010e-04 - val_loss: 0.1304 - 80ms/epoch - 6ms/step
# Epoch 11/164
# 14/14 - 0s - loss: 7.2562e-04 - val_loss: 0.1227 - 77ms/epoch - 6ms/step
# Epoch 12/164
# 14/14 - 0s - loss: 6.7019e-04 - val_loss: 0.1150 - 77ms/epoch - 5ms/step
# Epoch 13/164
# 14/14 - 0s - loss: 6.1629e-04 - val_loss: 0.1081 - 78ms/epoch - 6ms/step
# Epoch 14/164
# 14/14 - 0s - loss: 5.7396e-04 - val_loss: 0.1018 - 77ms/epoch - 6ms/step
# Epoch 15/164
# 14/14 - 0s - loss: 5.4207e-04 - val_loss: 0.0963 - 78ms/epoch - 6ms/step
# Epoch 16/164
# 14/14 - 0s - loss: 5.1202e-04 - val_loss: 0.0913 - 77ms/epoch - 5ms/step
# Epoch 17/164
# 14/14 - 0s - loss: 4.8643e-04 - val_loss: 0.0866 - 76ms/epoch - 5ms/step
# Epoch 18/164
# 14/14 - 0s - loss: 4.6425e-04 - val_loss: 0.0825 - 77ms/epoch - 5ms/step
# Epoch 19/164
# 14/14 - 0s - loss: 4.4251e-04 - val_loss: 0.0786 - 91ms/epoch - 6ms/step
# Epoch 20/164
# 14/14 - 0s - loss: 4.2207e-04 - val_loss: 0.0749 - 77ms/epoch - 5ms/step
# Epoch 21/164
# 14/14 - 0s - loss: 4.0373e-04 - val_loss: 0.0715 - 76ms/epoch - 5ms/step
# Epoch 22/164
# 14/14 - 0s - loss: 3.8605e-04 - val_loss: 0.0682 - 76ms/epoch - 5ms/step
# Epoch 23/164
# 14/14 - 0s - loss: 3.6876e-04 - val_loss: 0.0651 - 77ms/epoch - 5ms/step
# Epoch 24/164
# 14/14 - 0s - loss: 3.5295e-04 - val_loss: 0.0621 - 78ms/epoch - 6ms/step
# Epoch 25/164
# 14/14 - 0s - loss: 3.3831e-04 - val_loss: 0.0593 - 77ms/epoch - 5ms/step
# Epoch 26/164
# 14/14 - 0s - loss: 3.2403e-04 - val_loss: 0.0565 - 77ms/epoch - 5ms/step
# Epoch 27/164
# 14/14 - 0s - loss: 3.1048e-04 - val_loss: 0.0539 - 77ms/epoch - 6ms/step
# Epoch 28/164
# 14/14 - 0s - loss: 2.9818e-04 - val_loss: 0.0514 - 79ms/epoch - 6ms/step
# Epoch 29/164
# 14/14 - 0s - loss: 2.8673e-04 - val_loss: 0.0490 - 90ms/epoch - 6ms/step
# Epoch 30/164
# 14/14 - 0s - loss: 2.7573e-04 - val_loss: 0.0467 - 90ms/epoch - 6ms/step
# Epoch 31/164
# 14/14 - 0s - loss: 2.6533e-04 - val_loss: 0.0445 - 126ms/epoch - 9ms/step
# Epoch 32/164
# 14/14 - 0s - loss: 2.5583e-04 - val_loss: 0.0425 - 91ms/epoch - 7ms/step
# Epoch 33/164
# 14/14 - 0s - loss: 2.4721e-04 - val_loss: 0.0405 - 89ms/epoch - 6ms/step
# Epoch 34/164
# 14/14 - 0s - loss: 2.3910e-04 - val_loss: 0.0386 - 83ms/epoch - 6ms/step
# Epoch 35/164
# 14/14 - 0s - loss: 2.3126e-04 - val_loss: 0.0368 - 89ms/epoch - 6ms/step
# Epoch 36/164
# 14/14 - 0s - loss: 2.2383e-04 - val_loss: 0.0351 - 88ms/epoch - 6ms/step
# Epoch 37/164
# 14/14 - 0s - loss: 2.1721e-04 - val_loss: 0.0334 - 86ms/epoch - 6ms/step
# Epoch 38/164
# 14/14 - 0s - loss: 2.1140e-04 - val_loss: 0.0319 - 88ms/epoch - 6ms/step
# Epoch 39/164
# 14/14 - 0s - loss: 2.0590e-04 - val_loss: 0.0304 - 89ms/epoch - 6ms/step
# Epoch 40/164
# 14/14 - 0s - loss: 2.0020e-04 - val_loss: 0.0290 - 87ms/epoch - 6ms/step
# Epoch 41/164
# 14/14 - 0s - loss: 1.9441e-04 - val_loss: 0.0277 - 87ms/epoch - 6ms/step
# Epoch 42/164
# 14/14 - 0s - loss: 1.8937e-04 - val_loss: 0.0264 - 88ms/epoch - 6ms/step
# Epoch 43/164
# 14/14 - 0s - loss: 1.8566e-04 - val_loss: 0.0252 - 84ms/epoch - 6ms/step
# Epoch 44/164
# 14/14 - 0s - loss: 1.8266e-04 - val_loss: 0.0241 - 84ms/epoch - 6ms/step
# Epoch 45/164
# 14/14 - 0s - loss: 1.7894e-04 - val_loss: 0.0231 - 83ms/epoch - 6ms/step
# Epoch 46/164
# 14/14 - 0s - loss: 1.7343e-04 - val_loss: 0.0220 - 81ms/epoch - 6ms/step
# Epoch 47/164
# 14/14 - 0s - loss: 1.6739e-04 - val_loss: 0.0210 - 82ms/epoch - 6ms/step
# Epoch 48/164
# 14/14 - 0s - loss: 1.6404e-04 - val_loss: 0.0200 - 80ms/epoch - 6ms/step
# Epoch 49/164
# 14/14 - 0s - loss: 1.6418e-04 - val_loss: 0.0192 - 82ms/epoch - 6ms/step
# Epoch 50/164
# 14/14 - 0s - loss: 1.6620e-04 - val_loss: 0.0186 - 81ms/epoch - 6ms/step
# Epoch 51/164
# 14/14 - 0s - loss: 1.6713e-04 - val_loss: 0.0179 - 82ms/epoch - 6ms/step
# Epoch 52/164
# 14/14 - 0s - loss: 1.5846e-04 - val_loss: 0.0169 - 80ms/epoch - 6ms/step
# Epoch 53/164
# 14/14 - 0s - loss: 1.4347e-04 - val_loss: 0.0158 - 81ms/epoch - 6ms/step
# Epoch 54/164
# 14/14 - 0s - loss: 1.4909e-04 - val_loss: 0.0149 - 81ms/epoch - 6ms/step
# Epoch 55/164
# 14/14 - 0s - loss: 1.6817e-04 - val_loss: 0.0146 - 81ms/epoch - 6ms/step
# Epoch 56/164
# 14/14 - 0s - loss: 1.7547e-04 - val_loss: 0.0149 - 111ms/epoch - 8ms/step
# Epoch 57/164
# 14/14 - 0s - loss: 2.5395e-04 - val_loss: 0.0152 - 79ms/epoch - 6ms/step
# Epoch 58/164
# 14/14 - 0s - loss: 4.0111e-04 - val_loss: 0.0146 - 78ms/epoch - 6ms/step
# Epoch 59/164
# 14/14 - 0s - loss: 3.1449e-04 - val_loss: 0.0128 - 80ms/epoch - 6ms/step
# Epoch 60/164
# 14/14 - 0s - loss: 2.5497e-04 - val_loss: 0.0109 - 82ms/epoch - 6ms/step
# Epoch 61/164
# 14/14 - 0s - loss: 0.0012 - val_loss: 0.0105 - 82ms/epoch - 6ms/step
# Epoch 62/164
# 14/14 - 0s - loss: 0.0020 - val_loss: 0.0135 - 81ms/epoch - 6ms/step
# Epoch 63/164
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0234 - 80ms/epoch - 6ms/step
# Epoch 64/164
# 14/14 - 0s - loss: 0.0044 - val_loss: 0.0396 - 81ms/epoch - 6ms/step
# Epoch 65/164
# 14/14 - 0s - loss: 0.0148 - val_loss: 0.0545 - 80ms/epoch - 6ms/step
# Epoch 66/164
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0529 - 80ms/epoch - 6ms/step
# Epoch 67/164
# 14/14 - 0s - loss: 0.0146 - val_loss: 0.0178 - 81ms/epoch - 6ms/step
# Epoch 68/164
# 14/14 - 0s - loss: 0.0433 - val_loss: 0.1403 - 80ms/epoch - 6ms/step
# Epoch 69/164
# 14/14 - 0s - loss: 0.0157 - val_loss: 0.2151 - 80ms/epoch - 6ms/step
# Epoch 70/164
# 14/14 - 0s - loss: 0.0375 - val_loss: 0.1370 - 80ms/epoch - 6ms/step
# Epoch 71/164
# 14/14 - 0s - loss: 0.0063 - val_loss: 0.0788 - 81ms/epoch - 6ms/step
# Epoch 72/164
# 14/14 - 0s - loss: 0.0149 - val_loss: 0.1721 - 80ms/epoch - 6ms/step
# Epoch 73/164
# 14/14 - 0s - loss: 0.0042 - val_loss: 0.1515 - 80ms/epoch - 6ms/step
# Epoch 74/164
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0844 - 81ms/epoch - 6ms/step
# Epoch 75/164
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0935 - 80ms/epoch - 6ms/step
# Epoch 76/164
# 14/14 - 0s - loss: 4.6114e-04 - val_loss: 0.0940 - 80ms/epoch - 6ms/step
# Epoch 77/164
# 14/14 - 0s - loss: 3.0129e-04 - val_loss: 0.0789 - 80ms/epoch - 6ms/step
# Epoch 78/164
# 14/14 - 0s - loss: 2.9612e-04 - val_loss: 0.0751 - 109ms/epoch - 8ms/step
# Epoch 79/164
# 14/14 - 0s - loss: 2.5527e-04 - val_loss: 0.0716 - 81ms/epoch - 6ms/step
# Epoch 80/164
# 14/14 - 0s - loss: 2.4356e-04 - val_loss: 0.0663 - 92ms/epoch - 7ms/step
# Epoch 81/164
# 14/14 - 0s - loss: 2.3833e-04 - val_loss: 0.0627 - 80ms/epoch - 6ms/step
# Epoch 82/164
# 14/14 - 0s - loss: 2.2963e-04 - val_loss: 0.0596 - 81ms/epoch - 6ms/step
# Epoch 83/164
# 14/14 - 0s - loss: 2.2295e-04 - val_loss: 0.0563 - 80ms/epoch - 6ms/step
# Epoch 84/164
# 14/14 - 0s - loss: 2.1768e-04 - val_loss: 0.0536 - 81ms/epoch - 6ms/step
# Epoch 85/164
# 14/14 - 0s - loss: 2.1193e-04 - val_loss: 0.0510 - 81ms/epoch - 6ms/step
# Epoch 86/164
# 14/14 - 0s - loss: 2.0662e-04 - val_loss: 0.0486 - 81ms/epoch - 6ms/step
# Epoch 87/164
# 14/14 - 0s - loss: 2.0198e-04 - val_loss: 0.0463 - 80ms/epoch - 6ms/step
# Epoch 88/164
# 14/14 - 0s - loss: 1.9739e-04 - val_loss: 0.0442 - 81ms/epoch - 6ms/step
# Epoch 89/164
# 14/14 - 0s - loss: 1.9298e-04 - val_loss: 0.0421 - 80ms/epoch - 6ms/step
# Epoch 90/164
# 14/14 - 0s - loss: 1.8900e-04 - val_loss: 0.0402 - 80ms/epoch - 6ms/step
# Epoch 91/164
# 14/14 - 0s - loss: 1.8518e-04 - val_loss: 0.0384 - 81ms/epoch - 6ms/step
# Epoch 92/164
# 14/14 - 0s - loss: 1.8149e-04 - val_loss: 0.0367 - 81ms/epoch - 6ms/step
# Epoch 93/164
# 14/14 - 0s - loss: 1.7808e-04 - val_loss: 0.0350 - 78ms/epoch - 6ms/step
# Epoch 94/164
# 14/14 - 0s - loss: 1.7485e-04 - val_loss: 0.0334 - 81ms/epoch - 6ms/step
# Epoch 95/164
# 14/14 - 0s - loss: 1.7173e-04 - val_loss: 0.0319 - 81ms/epoch - 6ms/step
# Epoch 96/164
# 14/14 - 0s - loss: 1.6880e-04 - val_loss: 0.0305 - 82ms/epoch - 6ms/step
# Epoch 97/164
# 14/14 - 0s - loss: 1.6605e-04 - val_loss: 0.0291 - 89ms/epoch - 6ms/step
# Epoch 98/164
# 14/14 - 0s - loss: 1.6340e-04 - val_loss: 0.0278 - 95ms/epoch - 7ms/step
# Epoch 99/164
# 14/14 - 0s - loss: 1.6087e-04 - val_loss: 0.0265 - 82ms/epoch - 6ms/step
# Epoch 100/164
# 14/14 - 0s - loss: 1.5849e-04 - val_loss: 0.0253 - 81ms/epoch - 6ms/step
# Epoch 101/164
# 14/14 - 0s - loss: 1.5621e-04 - val_loss: 0.0242 - 81ms/epoch - 6ms/step
# Epoch 102/164
# 14/14 - 0s - loss: 1.5402e-04 - val_loss: 0.0231 - 113ms/epoch - 8ms/step
# Epoch 103/164
# 14/14 - 0s - loss: 1.5195e-04 - val_loss: 0.0220 - 80ms/epoch - 6ms/step
# Epoch 104/164
# 14/14 - 0s - loss: 1.4997e-04 - val_loss: 0.0210 - 81ms/epoch - 6ms/step
# Epoch 105/164
# 14/14 - 0s - loss: 1.4806e-04 - val_loss: 0.0201 - 77ms/epoch - 5ms/step
# Epoch 106/164
# 14/14 - 0s - loss: 1.4624e-04 - val_loss: 0.0191 - 77ms/epoch - 5ms/step
# Epoch 107/164
# 14/14 - 0s - loss: 1.4451e-04 - val_loss: 0.0183 - 77ms/epoch - 5ms/step
# Epoch 108/164
# 14/14 - 0s - loss: 1.4283e-04 - val_loss: 0.0174 - 77ms/epoch - 5ms/step
# Epoch 109/164
# 14/14 - 0s - loss: 1.4122e-04 - val_loss: 0.0166 - 76ms/epoch - 5ms/step
# Epoch 110/164
# 14/14 - 0s - loss: 1.3968e-04 - val_loss: 0.0159 - 77ms/epoch - 5ms/step
# Epoch 111/164
# 14/14 - 0s - loss: 1.3820e-04 - val_loss: 0.0151 - 76ms/epoch - 5ms/step
# Epoch 112/164
# 14/14 - 0s - loss: 1.3677e-04 - val_loss: 0.0145 - 76ms/epoch - 5ms/step
# Epoch 113/164
# 14/14 - 0s - loss: 1.3539e-04 - val_loss: 0.0138 - 76ms/epoch - 5ms/step
# Epoch 114/164
# 14/14 - 0s - loss: 1.3408e-04 - val_loss: 0.0132 - 77ms/epoch - 5ms/step
# Epoch 115/164
# 14/14 - 0s - loss: 1.3281e-04 - val_loss: 0.0126 - 75ms/epoch - 5ms/step
# Epoch 116/164
# 14/14 - 0s - loss: 1.3158e-04 - val_loss: 0.0120 - 77ms/epoch - 5ms/step
# Epoch 117/164
# 14/14 - 0s - loss: 1.3040e-04 - val_loss: 0.0115 - 77ms/epoch - 5ms/step
# Epoch 118/164
# 14/14 - 0s - loss: 1.2926e-04 - val_loss: 0.0110 - 76ms/epoch - 5ms/step
# Epoch 119/164
# 14/14 - 0s - loss: 1.2817e-04 - val_loss: 0.0105 - 79ms/epoch - 6ms/step
# Epoch 120/164
# 14/14 - 0s - loss: 1.2711e-04 - val_loss: 0.0100 - 77ms/epoch - 6ms/step
# Epoch 121/164
# 14/14 - 0s - loss: 1.2610e-04 - val_loss: 0.0096 - 76ms/epoch - 5ms/step
# Epoch 122/164
# 14/14 - 0s - loss: 1.2512e-04 - val_loss: 0.0092 - 76ms/epoch - 5ms/step
# Epoch 123/164
# 14/14 - 0s - loss: 1.2418e-04 - val_loss: 0.0088 - 76ms/epoch - 5ms/step
# Epoch 124/164
# 14/14 - 0s - loss: 1.2327e-04 - val_loss: 0.0085 - 76ms/epoch - 5ms/step
# Epoch 125/164
# 14/14 - 0s - loss: 1.2239e-04 - val_loss: 0.0082 - 77ms/epoch - 6ms/step
# Epoch 126/164
# 14/14 - 0s - loss: 1.2155e-04 - val_loss: 0.0078 - 76ms/epoch - 5ms/step
# Epoch 127/164
# 14/14 - 0s - loss: 1.2074e-04 - val_loss: 0.0075 - 109ms/epoch - 8ms/step
# Epoch 128/164
# 14/14 - 0s - loss: 1.1996e-04 - val_loss: 0.0073 - 77ms/epoch - 6ms/step
# Epoch 129/164
# 14/14 - 0s - loss: 1.1921e-04 - val_loss: 0.0070 - 77ms/epoch - 5ms/step
# Epoch 130/164
# 14/14 - 0s - loss: 1.1849e-04 - val_loss: 0.0068 - 77ms/epoch - 5ms/step
# Epoch 131/164
# 14/14 - 0s - loss: 1.1779e-04 - val_loss: 0.0065 - 76ms/epoch - 5ms/step
# Epoch 132/164
# 14/14 - 0s - loss: 1.1713e-04 - val_loss: 0.0063 - 76ms/epoch - 5ms/step
# Epoch 133/164
# 14/14 - 0s - loss: 1.1648e-04 - val_loss: 0.0061 - 76ms/epoch - 5ms/step
# Epoch 134/164
# 14/14 - 0s - loss: 1.1586e-04 - val_loss: 0.0060 - 77ms/epoch - 5ms/step
# Epoch 135/164
# 14/14 - 0s - loss: 1.1526e-04 - val_loss: 0.0058 - 77ms/epoch - 5ms/step
# Epoch 136/164
# 14/14 - 0s - loss: 1.1469e-04 - val_loss: 0.0056 - 76ms/epoch - 5ms/step
# Epoch 137/164
# 14/14 - 0s - loss: 1.1415e-04 - val_loss: 0.0055 - 76ms/epoch - 5ms/step
# Epoch 138/164
# 14/14 - 0s - loss: 1.1361e-04 - val_loss: 0.0054 - 76ms/epoch - 5ms/step
# Epoch 139/164
# 14/14 - 0s - loss: 1.1309e-04 - val_loss: 0.0052 - 76ms/epoch - 5ms/step
# Epoch 140/164
# 14/14 - 0s - loss: 1.1259e-04 - val_loss: 0.0051 - 76ms/epoch - 5ms/step
# Epoch 141/164
# 14/14 - 0s - loss: 1.1213e-04 - val_loss: 0.0050 - 76ms/epoch - 5ms/step
# Epoch 142/164
# 14/14 - 0s - loss: 1.1168e-04 - val_loss: 0.0049 - 77ms/epoch - 5ms/step
# Epoch 143/164
# 14/14 - 0s - loss: 1.1123e-04 - val_loss: 0.0048 - 76ms/epoch - 5ms/step
# Epoch 144/164
# 14/14 - 0s - loss: 1.1077e-04 - val_loss: 0.0048 - 77ms/epoch - 5ms/step
# Epoch 145/164
# 14/14 - 0s - loss: 1.1034e-04 - val_loss: 0.0047 - 88ms/epoch - 6ms/step
# Epoch 146/164
# 14/14 - 0s - loss: 1.0996e-04 - val_loss: 0.0046 - 77ms/epoch - 5ms/step
# Epoch 147/164
# 14/14 - 0s - loss: 1.0962e-04 - val_loss: 0.0046 - 79ms/epoch - 6ms/step
# Epoch 148/164
# 14/14 - 0s - loss: 1.0927e-04 - val_loss: 0.0045 - 76ms/epoch - 5ms/step
# Epoch 149/164
# 14/14 - 0s - loss: 1.0884e-04 - val_loss: 0.0045 - 76ms/epoch - 5ms/step
# Epoch 150/164
# 14/14 - 0s - loss: 1.0837e-04 - val_loss: 0.0044 - 76ms/epoch - 5ms/step
# Epoch 151/164
# 14/14 - 0s - loss: 1.0799e-04 - val_loss: 0.0044 - 107ms/epoch - 8ms/step
# Epoch 152/164
# 14/14 - 0s - loss: 1.0781e-04 - val_loss: 0.0044 - 78ms/epoch - 6ms/step
# Epoch 153/164
# 14/14 - 0s - loss: 1.0774e-04 - val_loss: 0.0043 - 78ms/epoch - 6ms/step
# Epoch 154/164
# 14/14 - 0s - loss: 1.0747e-04 - val_loss: 0.0043 - 75ms/epoch - 5ms/step
# Epoch 155/164
# 14/14 - 0s - loss: 1.0677e-04 - val_loss: 0.0043 - 76ms/epoch - 5ms/step
# Epoch 156/164
# 14/14 - 0s - loss: 1.0588e-04 - val_loss: 0.0043 - 77ms/epoch - 5ms/step
# Epoch 157/164
# 14/14 - 0s - loss: 1.0554e-04 - val_loss: 0.0043 - 77ms/epoch - 5ms/step
# Epoch 158/164
# 14/14 - 0s - loss: 1.0617e-04 - val_loss: 0.0043 - 77ms/epoch - 5ms/step
# Epoch 159/164
# 14/14 - 0s - loss: 1.0747e-04 - val_loss: 0.0043 - 76ms/epoch - 5ms/step
# Epoch 160/164
# 14/14 - 0s - loss: 1.0806e-04 - val_loss: 0.0042 - 76ms/epoch - 5ms/step
# Epoch 161/164
# 14/14 - 0s - loss: 1.0570e-04 - val_loss: 0.0042 - 76ms/epoch - 5ms/step
# Epoch 162/164
# 14/14 - 0s - loss: 1.0195e-04 - val_loss: 0.0042 - 76ms/epoch - 5ms/step
# Epoch 163/164
# 14/14 - 0s - loss: 1.0267e-04 - val_loss: 0.0043 - 76ms/epoch - 5ms/step
# Epoch 164/164
# 14/14 - 0s - loss: 1.0802e-04 - val_loss: 0.0044 - 77ms/epoch - 5ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_2 (GRU)                 (None, 3, 128)            55680
#
#  gru_3 (GRU)                 (None, 64)                37248
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 95041 (371.25 KB)
# Trainable params: 95041 (371.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# /Users/najwarujok/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 0.06617061700643975

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_log_error, mean_absolute_percentage_error
# %% --------------------------------------- Plot the result  -----------------------------------------------------------------
## TRAIN DATA
def plot_traindataset_result(X_train, y_train):
    train_yhat = model.predict(X_train, verbose=0)

    y_scaler = load(open('y_scaler.pkl', 'rb'))
    train_predict_index = np.load("index_train.npy", allow_pickle=True)

    rescaled_real_y = y_scaler.inverse_transform(y_train)
    rescaled_predicted_y = y_scaler.inverse_transform(train_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=train_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=train_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Train", fontsize=20)
    plt.show()

   # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    print('-- Test RMSE -- ', RMSE)

    # Calculate MAE
    MAE = mean_absolute_error(real, predicted)
    print('-- MAE -- ', MAE)

    # Calculate R2
    R2 = r2_score(real, predicted)
    print('-- R2 -- ', R2)

    # Calculate MSLE
    MSLE = mean_squared_log_error(real, predicted)
    print('-- MSLE -- ', MSLE)

    # Calculate MAPE
    MAPE = mean_absolute_percentage_error(real, predicted)
    print('-- MAPE -- ', MAPE)

    return predict_result, RMSE, MAE, R2, MSLE, MAPE
    
train_predicted, train_RMSE, train_MAE, train_R2, train_MSLE, train_MAPE  = plot_traindataset_result(X_train, y_train)
# Out:
# -- Test RMSE --  0.9158598376034643
# -- MAE --  0.6856626337521698
# -- R2 --  0.9947812802568504
# -- MSLE --  0.0007070358822736513
# -- MAPE --  0.021612238652351276

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_log_error, mean_absolute_percentage_error

# %% --------------------------------------- Plot the result  -----------------------------------------------------------------
def plot_testdataset_result(X_test, y_test):

    test_yhat = model.predict(X_test, verbose=0)
    y_scaler = load(open('y_scaler.pkl', 'rb'))
    test_predict_index = np.load("index_test.npy", allow_pickle=True)

    rescaled_real_y = y_scaler.inverse_transform(y_test)
    rescaled_predicted_y = y_scaler.inverse_transform(test_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=test_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=test_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    print(predict_result.tail(10))

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Testing", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    print('-- Train RMSE -- ', RMSE)

     # Calculate MAE
    MAE = mean_absolute_error(real, predicted)
    print('-- MAE -- ', MAE)

    # Calculate R2
    R2 = r2_score(real, predicted)
    print('-- R2 -- ', R2)

    # Calculate MSLE
    MSLE = mean_squared_log_error(real, predicted)
    print('-- MSLE -- ', MSLE)

    # Calculate MAPE
    MAPE = mean_absolute_percentage_error(real, predicted)
    print('-- MAPE -- ', MAPE)

    return predict_result, RMSE, MAE, R2, MSLE, MAPE


test_predicted, test_RMSE, test_MAE, test_R2, test_MSLE, test_MAPE  = plot_testdataset_result(X_test, y_test)
print("----- Test_RMSE_GRU -----", test_RMSE)
# Out:
#             predicted_price  predicted_price  predicted_price  \
# 2022-12-16              NaN              NaN              NaN
# 2022-12-19              NaN              NaN              NaN
# 2022-12-20              NaN              NaN              NaN
# 2022-12-21              NaN              NaN              NaN
# 2022-12-22              NaN              NaN              NaN
# 2022-12-23              NaN              NaN              NaN
# 2022-12-27              NaN              NaN              NaN
# 2022-12-28              NaN              NaN              NaN
# 2022-12-29              NaN              NaN              NaN
# 2022-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2022-12-16              NaN              NaN              NaN
# 2022-12-19              NaN              NaN              NaN
# 2022-12-20              NaN              NaN              NaN
# 2022-12-21              NaN              NaN              NaN
# 2022-12-22              NaN              NaN              NaN
# 2022-12-23              NaN              NaN              NaN
# 2022-12-27              NaN              NaN              NaN
# 2022-12-28              NaN              NaN              NaN
# 2022-12-29              NaN              NaN              NaN
# 2022-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2022-12-16              NaN              NaN              NaN
# 2022-12-19              NaN              NaN              NaN
# 2022-12-20              NaN              NaN              NaN
# 2022-12-21              NaN              NaN              NaN
# 2022-12-22              NaN              NaN              NaN
# 2022-12-23              NaN              NaN              NaN
# 2022-12-27              NaN              NaN              NaN
# 2022-12-28              NaN              NaN              NaN
# 2022-12-29              NaN              NaN              NaN
# 2022-12-30              NaN              NaN              NaN
#
#             predicted_price  ...  predicted_price  predicted_price  \
# 2022-12-16              NaN  ...              NaN              NaN
# 2022-12-19              NaN  ...       131.832413              NaN
# 2022-12-20              NaN  ...              NaN       129.027847
# 2022-12-21              NaN  ...              NaN              NaN
# 2022-12-22              NaN  ...              NaN              NaN
# 2022-12-23              NaN  ...              NaN              NaN
# 2022-12-27              NaN  ...              NaN              NaN
# 2022-12-28              NaN  ...              NaN              NaN
# 2022-12-29              NaN  ...              NaN              NaN
# 2022-12-30              NaN  ...              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2022-12-16              NaN              NaN              NaN
# 2022-12-19              NaN              NaN              NaN
# 2022-12-20              NaN              NaN              NaN
# 2022-12-21       126.946854              NaN              NaN
# 2022-12-22              NaN       126.429825              NaN
# 2022-12-23              NaN              NaN        125.66993
# 2022-12-27              NaN              NaN              NaN
# 2022-12-28              NaN              NaN              NaN
# 2022-12-29              NaN              NaN              NaN
# 2022-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2022-12-16              NaN              NaN              NaN
# 2022-12-19              NaN              NaN              NaN
# 2022-12-20              NaN              NaN              NaN
# 2022-12-21              NaN              NaN              NaN
# 2022-12-22              NaN              NaN              NaN
# 2022-12-23              NaN              NaN              NaN
# 2022-12-27       124.781242              NaN              NaN
# 2022-12-28              NaN       123.396919              NaN
# 2022-12-29              NaN              NaN       121.783913
# 2022-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_mean
# 2022-12-16              NaN      134.547714
# 2022-12-19              NaN      131.832413
# 2022-12-20              NaN      129.027847
# 2022-12-21              NaN      126.946854
# 2022-12-22              NaN      126.429825
# 2022-12-23              NaN      125.669930
# 2022-12-27              NaN      124.781242
# 2022-12-28              NaN      123.396919
# 2022-12-29              NaN      121.783913
# 2022-12-30       121.072739      121.072739
#
# [10 rows x 752 columns]
# -- Train RMSE --  5.560399401016762
# -- MAE --  4.384311630309977
# -- R2 --  0.9671825770361898
# -- MSLE --  0.0017515967652569975
# -- MAPE --  0.03353558351758441
# ----- Test_RMSE_GRU ----- 5.560399401016762
