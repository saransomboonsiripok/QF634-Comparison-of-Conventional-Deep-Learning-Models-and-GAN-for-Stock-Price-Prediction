# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow

from numpy import *
from math import sqrt
from pandas import *
from datetime import datetime, timedelta

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Bidirectional
from tensorflow.keras.layers import BatchNormalization, Embedding, TimeDistributed, LeakyReLU
from tensorflow.keras.layers import LSTM, GRU
from tensorflow.keras.optimizers import Adam

from matplotlib import pyplot
from pickle import load
# Out:
# 2023-12-05 23:40:28.260855: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# import data

X_train = np.load("X_train.npy", allow_pickle=True)
y_train = np.load("y_train.npy", allow_pickle=True)
X_test = np.load("X_test.npy", allow_pickle=True)
y_test = np.load("y_test.npy", allow_pickle=True)
yc_train = np.load("yc_train.npy", allow_pickle=True)
yc_test = np.load("yc_test.npy", allow_pickle=True)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_log_error, mean_absolute_percentage_error

#Parameters
LR = 0.001
BATCH_SIZE = 64
N_EPOCH = 250

input_dim = X_train.shape[1]
feature_size = X_train.shape[2]
output_dim = y_train.shape[1]

def basic_lstm(input_dim, feature_size):
    model = Sequential()
    model.add(Bidirectional(LSTM(units= 128), input_shape=(input_dim, feature_size)))
    model.add(Dense(64))
    model.add(Dense(units=output_dim))
    model.compile(optimizer=Adam(lr = LR), loss='mse')
    history = model.fit(X_train, y_train, epochs=N_EPOCH, batch_size=BATCH_SIZE, validation_data=(X_test, y_test),
                        verbose=2, shuffle=False)

    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='validation')
    pyplot.legend()
    pyplot.show()

    return model

model = basic_lstm(input_dim, feature_size)
model.save('LSTM_3to1.h5')
print(model.summary())

yhat = model.predict(X_test, verbose=0)
#print(yhat)

rmse = sqrt(mean_squared_error(y_test, yhat))
print(rmse)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/164
# 28/28 - 26s - loss: 0.0753 - val_loss: 0.0719 - 26s/epoch - 916ms/step
# Epoch 2/164
# 28/28 - 0s - loss: 0.0250 - val_loss: 0.0471 - 415ms/epoch - 15ms/step
# Epoch 3/164
# 28/28 - 1s - loss: 0.0119 - val_loss: 0.0626 - 588ms/epoch - 21ms/step
# Epoch 4/164
# 28/28 - 0s - loss: 0.0310 - val_loss: 0.0405 - 476ms/epoch - 17ms/step
# Epoch 5/164
# 28/28 - 0s - loss: 0.0216 - val_loss: 0.0226 - 473ms/epoch - 17ms/step
# Epoch 6/164
# 28/28 - 0s - loss: 0.0210 - val_loss: 0.1011 - 442ms/epoch - 16ms/step
# Epoch 7/164
# 28/28 - 0s - loss: 0.0545 - val_loss: 0.0655 - 451ms/epoch - 16ms/step
# Epoch 8/164
# 28/28 - 0s - loss: 0.0242 - val_loss: 0.0558 - 356ms/epoch - 13ms/step
# Epoch 9/164
# 28/28 - 0s - loss: 0.0253 - val_loss: 0.0967 - 350ms/epoch - 13ms/step
# Epoch 10/164
# 28/28 - 0s - loss: 0.0412 - val_loss: 0.0176 - 396ms/epoch - 14ms/step
# Epoch 11/164
# 28/28 - 0s - loss: 0.0170 - val_loss: 0.0236 - 354ms/epoch - 13ms/step
# Epoch 12/164
# 28/28 - 0s - loss: 0.0141 - val_loss: 0.0407 - 365ms/epoch - 13ms/step
# Epoch 13/164
# 28/28 - 0s - loss: 0.0110 - val_loss: 0.0388 - 460ms/epoch - 16ms/step
# Epoch 14/164
# 28/28 - 0s - loss: 0.0200 - val_loss: 0.0290 - 391ms/epoch - 14ms/step
# Epoch 15/164
# 28/28 - 0s - loss: 0.0100 - val_loss: 0.0065 - 377ms/epoch - 13ms/step
# Epoch 16/164
# 28/28 - 0s - loss: 0.0087 - val_loss: 0.0322 - 430ms/epoch - 15ms/step
# Epoch 17/164
# 28/28 - 1s - loss: 0.0082 - val_loss: 0.0233 - 503ms/epoch - 18ms/step
# Epoch 18/164
# 28/28 - 0s - loss: 0.0039 - val_loss: 0.0144 - 407ms/epoch - 15ms/step
# Epoch 19/164
# 28/28 - 0s - loss: 0.0068 - val_loss: 0.0089 - 422ms/epoch - 15ms/step
# Epoch 20/164
# 28/28 - 1s - loss: 0.0016 - val_loss: 0.0280 - 527ms/epoch - 19ms/step
# Epoch 21/164
# 28/28 - 0s - loss: 0.0045 - val_loss: 0.0341 - 407ms/epoch - 15ms/step
# Epoch 22/164
# 28/28 - 0s - loss: 0.0015 - val_loss: 0.0222 - 452ms/epoch - 16ms/step
# Epoch 23/164
# 28/28 - 0s - loss: 0.0027 - val_loss: 0.0130 - 428ms/epoch - 15ms/step
# Epoch 24/164
# 28/28 - 0s - loss: 0.0023 - val_loss: 0.0183 - 399ms/epoch - 14ms/step
# Epoch 25/164
# 28/28 - 0s - loss: 0.0013 - val_loss: 0.0429 - 392ms/epoch - 14ms/step
# Epoch 26/164
# 28/28 - 0s - loss: 0.0030 - val_loss: 0.0499 - 452ms/epoch - 16ms/step
# Epoch 27/164
# 28/28 - 0s - loss: 0.0017 - val_loss: 0.0322 - 466ms/epoch - 17ms/step
# Epoch 28/164
# 28/28 - 0s - loss: 0.0021 - val_loss: 0.0146 - 397ms/epoch - 14ms/step
# Epoch 29/164
# 28/28 - 0s - loss: 0.0041 - val_loss: 0.0102 - 426ms/epoch - 15ms/step
# Epoch 30/164
# 28/28 - 1s - loss: 0.0016 - val_loss: 0.0357 - 501ms/epoch - 18ms/step
# Epoch 31/164
# 28/28 - 0s - loss: 0.0037 - val_loss: 0.0822 - 447ms/epoch - 16ms/step
# Epoch 32/164
# 28/28 - 0s - loss: 0.0065 - val_loss: 0.0647 - 435ms/epoch - 16ms/step
# Epoch 33/164
# 28/28 - 1s - loss: 0.0030 - val_loss: 0.0279 - 606ms/epoch - 22ms/step
# Epoch 34/164
# 28/28 - 0s - loss: 0.0073 - val_loss: 0.0172 - 408ms/epoch - 15ms/step
# Epoch 35/164
# 28/28 - 0s - loss: 0.0142 - val_loss: 0.0062 - 420ms/epoch - 15ms/step
# Epoch 36/164
# 28/28 - 0s - loss: 0.0040 - val_loss: 0.0540 - 401ms/epoch - 14ms/step
# Epoch 37/164
# 28/28 - 0s - loss: 0.0113 - val_loss: 0.1393 - 414ms/epoch - 15ms/step
# Epoch 38/164
# 28/28 - 0s - loss: 0.0162 - val_loss: 0.0590 - 333ms/epoch - 12ms/step
# Epoch 39/164
# 28/28 - 0s - loss: 0.0054 - val_loss: 0.0340 - 431ms/epoch - 15ms/step
# Epoch 40/164
# 28/28 - 1s - loss: 0.0165 - val_loss: 0.0366 - 609ms/epoch - 22ms/step
# Epoch 41/164
# 28/28 - 0s - loss: 0.0150 - val_loss: 0.0075 - 484ms/epoch - 17ms/step
# Epoch 42/164
# 28/28 - 0s - loss: 0.0037 - val_loss: 0.1256 - 460ms/epoch - 16ms/step
# Epoch 43/164
# 28/28 - 0s - loss: 0.0162 - val_loss: 0.0934 - 497ms/epoch - 18ms/step
# Epoch 44/164
# 28/28 - 0s - loss: 0.0053 - val_loss: 0.0364 - 463ms/epoch - 17ms/step
# Epoch 45/164
# 28/28 - 0s - loss: 0.0055 - val_loss: 0.0222 - 427ms/epoch - 15ms/step
# Epoch 46/164
# 28/28 - 1s - loss: 0.0124 - val_loss: 0.0164 - 502ms/epoch - 18ms/step
# Epoch 47/164
# 28/28 - 0s - loss: 0.0020 - val_loss: 0.0971 - 401ms/epoch - 14ms/step
# Epoch 48/164
# 28/28 - 0s - loss: 0.0069 - val_loss: 0.1133 - 487ms/epoch - 17ms/step
# Epoch 49/164
# 28/28 - 1s - loss: 0.0038 - val_loss: 0.0487 - 529ms/epoch - 19ms/step
# Epoch 50/164
# 28/28 - 0s - loss: 0.0029 - val_loss: 0.0196 - 460ms/epoch - 16ms/step
# Epoch 51/164
# 28/28 - 1s - loss: 0.0059 - val_loss: 0.0307 - 647ms/epoch - 23ms/step
# Epoch 52/164
# 28/28 - 1s - loss: 0.0013 - val_loss: 0.0958 - 572ms/epoch - 20ms/step
# Epoch 53/164
# 28/28 - 0s - loss: 0.0035 - val_loss: 0.1164 - 415ms/epoch - 15ms/step
# Epoch 54/164
# 28/28 - 0s - loss: 0.0022 - val_loss: 0.0718 - 417ms/epoch - 15ms/step
# Epoch 55/164
# 28/28 - 0s - loss: 0.0014 - val_loss: 0.0395 - 467ms/epoch - 17ms/step
# Epoch 56/164
# 28/28 - 1s - loss: 0.0031 - val_loss: 0.0428 - 530ms/epoch - 19ms/step
# Epoch 57/164
# 28/28 - 0s - loss: 0.0013 - val_loss: 0.0901 - 451ms/epoch - 16ms/step
# Epoch 58/164
# 28/28 - 0s - loss: 0.0016 - val_loss: 0.1339 - 435ms/epoch - 16ms/step
# Epoch 59/164
# 28/28 - 0s - loss: 0.0024 - val_loss: 0.1093 - 434ms/epoch - 15ms/step
# Epoch 60/164
# 28/28 - 0s - loss: 0.0011 - val_loss: 0.0646 - 453ms/epoch - 16ms/step
# Epoch 61/164
# 28/28 - 0s - loss: 0.0019 - val_loss: 0.0406 - 409ms/epoch - 15ms/step
# Epoch 62/164
# 28/28 - 0s - loss: 0.0026 - val_loss: 0.0551 - 471ms/epoch - 17ms/step
# Epoch 63/164
# 28/28 - 0s - loss: 9.6923e-04 - val_loss: 0.1178 - 479ms/epoch - 17ms/step
# Epoch 64/164
# 28/28 - 0s - loss: 0.0023 - val_loss: 0.1627 - 476ms/epoch - 17ms/step
# Epoch 65/164
# 28/28 - 1s - loss: 0.0031 - val_loss: 0.1168 - 502ms/epoch - 18ms/step
# Epoch 66/164
# 28/28 - 1s - loss: 0.0015 - val_loss: 0.0563 - 503ms/epoch - 18ms/step
# Epoch 67/164
# 28/28 - 0s - loss: 0.0031 - val_loss: 0.0228 - 407ms/epoch - 15ms/step
# Epoch 68/164
# 28/28 - 0s - loss: 0.0053 - val_loss: 0.0308 - 473ms/epoch - 17ms/step
# Epoch 69/164
# 28/28 - 0s - loss: 0.0018 - val_loss: 0.1162 - 402ms/epoch - 14ms/step
# Epoch 70/164
# 28/28 - 0s - loss: 0.0037 - val_loss: 0.2167 - 468ms/epoch - 17ms/step
# Epoch 71/164
# 28/28 - 0s - loss: 0.0068 - val_loss: 0.1378 - 413ms/epoch - 15ms/step
# Epoch 72/164
# 28/28 - 0s - loss: 0.0035 - val_loss: 0.0538 - 417ms/epoch - 15ms/step
# Epoch 73/164
# 28/28 - 0s - loss: 0.0044 - val_loss: 0.0160 - 404ms/epoch - 14ms/step
# Epoch 74/164
# 28/28 - 0s - loss: 0.0112 - val_loss: 0.0117 - 457ms/epoch - 16ms/step
# Epoch 75/164
# 28/28 - 0s - loss: 0.0043 - val_loss: 0.0885 - 412ms/epoch - 15ms/step
# Epoch 76/164
# 28/28 - 0s - loss: 0.0031 - val_loss: 0.2721 - 342ms/epoch - 12ms/step
# Epoch 77/164
# 28/28 - 0s - loss: 0.0106 - val_loss: 0.1715 - 393ms/epoch - 14ms/step
# Epoch 78/164
# 28/28 - 0s - loss: 0.0046 - val_loss: 0.0542 - 357ms/epoch - 13ms/step
# Epoch 79/164
# 28/28 - 0s - loss: 0.0035 - val_loss: 0.0257 - 383ms/epoch - 14ms/step
# Epoch 80/164
# 28/28 - 0s - loss: 0.0120 - val_loss: 0.0143 - 350ms/epoch - 12ms/step
# Epoch 81/164
# 28/28 - 1s - loss: 0.0037 - val_loss: 0.0851 - 550ms/epoch - 20ms/step
# Epoch 82/164
# 28/28 - 0s - loss: 0.0022 - val_loss: 0.2886 - 347ms/epoch - 12ms/step
# Epoch 83/164
# 28/28 - 0s - loss: 0.0100 - val_loss: 0.1911 - 327ms/epoch - 12ms/step
# Epoch 84/164
# 28/28 - 0s - loss: 0.0035 - val_loss: 0.0597 - 447ms/epoch - 16ms/step
# Epoch 85/164
# 28/28 - 0s - loss: 0.0030 - val_loss: 0.0190 - 363ms/epoch - 13ms/step
# Epoch 86/164
# 28/28 - 0s - loss: 0.0089 - val_loss: 0.0386 - 369ms/epoch - 13ms/step
# Epoch 87/164
# 28/28 - 0s - loss: 0.0018 - val_loss: 0.1537 - 358ms/epoch - 13ms/step
# Epoch 88/164
# 28/28 - 0s - loss: 0.0031 - val_loss: 0.2427 - 471ms/epoch - 17ms/step
# Epoch 89/164
# 28/28 - 0s - loss: 0.0044 - val_loss: 0.1168 - 334ms/epoch - 12ms/step
# Epoch 90/164
# 28/28 - 0s - loss: 0.0016 - val_loss: 0.0437 - 334ms/epoch - 12ms/step
# Epoch 91/164
# 28/28 - 0s - loss: 0.0048 - val_loss: 0.0354 - 350ms/epoch - 12ms/step
# Epoch 92/164
# 28/28 - 0s - loss: 0.0030 - val_loss: 0.1201 - 371ms/epoch - 13ms/step
# Epoch 93/164
# 28/28 - 0s - loss: 0.0016 - val_loss: 0.2307 - 363ms/epoch - 13ms/step
# Epoch 94/164
# 28/28 - 0s - loss: 0.0036 - val_loss: 0.1665 - 377ms/epoch - 13ms/step
# Epoch 95/164
# 28/28 - 0s - loss: 0.0015 - val_loss: 0.0807 - 393ms/epoch - 14ms/step
# Epoch 96/164
# 28/28 - 0s - loss: 0.0022 - val_loss: 0.0461 - 374ms/epoch - 13ms/step
# Epoch 97/164
# 28/28 - 0s - loss: 0.0033 - val_loss: 0.0830 - 349ms/epoch - 12ms/step
# Epoch 98/164
# 28/28 - 0s - loss: 9.7003e-04 - val_loss: 0.1793 - 356ms/epoch - 13ms/step
# Epoch 99/164
# 28/28 - 0s - loss: 0.0021 - val_loss: 0.2111 - 472ms/epoch - 17ms/step
# Epoch 100/164
# 28/28 - 0s - loss: 0.0020 - val_loss: 0.1389 - 391ms/epoch - 14ms/step
# Epoch 101/164
# 28/28 - 0s - loss: 9.3985e-04 - val_loss: 0.0767 - 377ms/epoch - 13ms/step
# Epoch 102/164
# 28/28 - 0s - loss: 0.0022 - val_loss: 0.0599 - 348ms/epoch - 12ms/step
# Epoch 103/164
# 28/28 - 0s - loss: 0.0021 - val_loss: 0.1058 - 347ms/epoch - 12ms/step
# Epoch 104/164
# 28/28 - 0s - loss: 8.2956e-04 - val_loss: 0.1955 - 327ms/epoch - 12ms/step
# Epoch 105/164
# 28/28 - 0s - loss: 0.0021 - val_loss: 0.2127 - 398ms/epoch - 14ms/step
# Epoch 106/164
# 28/28 - 0s - loss: 0.0020 - val_loss: 0.1388 - 390ms/epoch - 14ms/step
# Epoch 107/164
# 28/28 - 0s - loss: 9.4283e-04 - val_loss: 0.0733 - 374ms/epoch - 13ms/step
# Epoch 108/164
# 28/28 - 0s - loss: 0.0024 - val_loss: 0.0480 - 381ms/epoch - 14ms/step
# Epoch 109/164
# 28/28 - 0s - loss: 0.0028 - val_loss: 0.0852 - 375ms/epoch - 13ms/step
# Epoch 110/164
# 28/28 - 0s - loss: 9.4902e-04 - val_loss: 0.1905 - 371ms/epoch - 13ms/step
# Epoch 111/164
# 28/28 - 0s - loss: 0.0024 - val_loss: 0.2460 - 343ms/epoch - 12ms/step
# Epoch 112/164
# 28/28 - 0s - loss: 0.0032 - val_loss: 0.1584 - 398ms/epoch - 14ms/step
# Epoch 113/164
# 28/28 - 0s - loss: 0.0015 - val_loss: 0.0739 - 378ms/epoch - 13ms/step
# Epoch 114/164
# 28/28 - 0s - loss: 0.0026 - val_loss: 0.0285 - 348ms/epoch - 12ms/step
# Epoch 115/164
# 28/28 - 0s - loss: 0.0053 - val_loss: 0.0421 - 392ms/epoch - 14ms/step
# Epoch 116/164
# 28/28 - 0s - loss: 0.0021 - val_loss: 0.1449 - 351ms/epoch - 13ms/step
# Epoch 117/164
# 28/28 - 0s - loss: 0.0022 - val_loss: 0.2862 - 350ms/epoch - 12ms/step
# Epoch 118/164
# 28/28 - 0s - loss: 0.0052 - val_loss: 0.2048 - 347ms/epoch - 12ms/step
# Epoch 119/164
# 28/28 - 0s - loss: 0.0032 - val_loss: 0.0923 - 362ms/epoch - 13ms/step
# Epoch 120/164
# 28/28 - 0s - loss: 0.0020 - val_loss: 0.0286 - 359ms/epoch - 13ms/step
# Epoch 121/164
# 28/28 - 0s - loss: 0.0069 - val_loss: 0.0181 - 352ms/epoch - 13ms/step
# Epoch 122/164
# 28/28 - 0s - loss: 0.0043 - val_loss: 0.0846 - 346ms/epoch - 12ms/step
# Epoch 123/164
# 28/28 - 0s - loss: 0.0014 - val_loss: 0.2662 - 343ms/epoch - 12ms/step
# Epoch 124/164
# 28/28 - 1s - loss: 0.0060 - val_loss: 0.2690 - 541ms/epoch - 19ms/step
# Epoch 125/164
# 28/28 - 0s - loss: 0.0034 - val_loss: 0.1048 - 334ms/epoch - 12ms/step
# Epoch 126/164
# 28/28 - 0s - loss: 0.0016 - val_loss: 0.0388 - 451ms/epoch - 16ms/step
# Epoch 127/164
# 28/28 - 0s - loss: 0.0057 - val_loss: 0.0169 - 367ms/epoch - 13ms/step
# Epoch 128/164
# 28/28 - 0s - loss: 0.0039 - val_loss: 0.0733 - 389ms/epoch - 14ms/step
# Epoch 129/164
# 28/28 - 0s - loss: 0.0013 - val_loss: 0.2468 - 369ms/epoch - 13ms/step
# Epoch 130/164
# 28/28 - 0s - loss: 0.0050 - val_loss: 0.2481 - 376ms/epoch - 13ms/step
# Epoch 131/164
# 28/28 - 0s - loss: 0.0026 - val_loss: 0.1020 - 353ms/epoch - 13ms/step
# Epoch 132/164
# 28/28 - 0s - loss: 0.0016 - val_loss: 0.0354 - 337ms/epoch - 12ms/step
# Epoch 133/164
# 28/28 - 0s - loss: 0.0055 - val_loss: 0.0292 - 348ms/epoch - 12ms/step
# Epoch 134/164
# 28/28 - 0s - loss: 0.0024 - val_loss: 0.1118 - 387ms/epoch - 14ms/step
# Epoch 135/164
# 28/28 - 0s - loss: 0.0017 - val_loss: 0.2641 - 405ms/epoch - 14ms/step
# Epoch 136/164
# 28/28 - 0s - loss: 0.0045 - val_loss: 0.1888 - 375ms/epoch - 13ms/step
# Epoch 137/164
# 28/28 - 0s - loss: 0.0017 - val_loss: 0.0804 - 319ms/epoch - 11ms/step
# Epoch 138/164
# 28/28 - 0s - loss: 0.0024 - val_loss: 0.0302 - 366ms/epoch - 13ms/step
# Epoch 139/164
# 28/28 - 0s - loss: 0.0048 - val_loss: 0.0580 - 334ms/epoch - 12ms/step
# Epoch 140/164
# 28/28 - 0s - loss: 0.0012 - val_loss: 0.1683 - 344ms/epoch - 12ms/step
# Epoch 141/164
# 28/28 - 0s - loss: 0.0025 - val_loss: 0.2379 - 371ms/epoch - 13ms/step
# Epoch 142/164
# 28/28 - 0s - loss: 0.0028 - val_loss: 0.1399 - 385ms/epoch - 14ms/step
# Epoch 143/164
# 28/28 - 0s - loss: 0.0010 - val_loss: 0.0636 - 354ms/epoch - 13ms/step
# Epoch 144/164
# 28/28 - 0s - loss: 0.0030 - val_loss: 0.0382 - 357ms/epoch - 13ms/step
# Epoch 145/164
# 28/28 - 0s - loss: 0.0028 - val_loss: 0.0899 - 353ms/epoch - 13ms/step
# Epoch 146/164
# 28/28 - 0s - loss: 9.3892e-04 - val_loss: 0.1948 - 369ms/epoch - 13ms/step
# Epoch 147/164
# 28/28 - 0s - loss: 0.0026 - val_loss: 0.1990 - 380ms/epoch - 14ms/step
# Epoch 148/164
# 28/28 - 0s - loss: 0.0016 - val_loss: 0.1181 - 395ms/epoch - 14ms/step
# Epoch 149/164
# 28/28 - 0s - loss: 0.0010 - val_loss: 0.0579 - 385ms/epoch - 14ms/step
# Epoch 150/164
# 28/28 - 0s - loss: 0.0028 - val_loss: 0.0493 - 392ms/epoch - 14ms/step
# Epoch 151/164
# 28/28 - 0s - loss: 0.0016 - val_loss: 0.1076 - 387ms/epoch - 14ms/step
# Epoch 152/164
# 28/28 - 0s - loss: 0.0011 - val_loss: 0.1984 - 353ms/epoch - 13ms/step
# Epoch 153/164
# 28/28 - 1s - loss: 0.0024 - val_loss: 0.1846 - 559ms/epoch - 20ms/step
# Epoch 154/164
# 28/28 - 0s - loss: 0.0013 - val_loss: 0.1106 - 375ms/epoch - 13ms/step
# Epoch 155/164
# 28/28 - 0s - loss: 0.0011 - val_loss: 0.0533 - 351ms/epoch - 13ms/step
# Epoch 156/164
# 28/28 - 0s - loss: 0.0028 - val_loss: 0.0448 - 393ms/epoch - 14ms/step
# Epoch 157/164
# 28/28 - 0s - loss: 0.0016 - val_loss: 0.0999 - 369ms/epoch - 13ms/step
# Epoch 158/164
# 28/28 - 0s - loss: 0.0011 - val_loss: 0.1969 - 356ms/epoch - 13ms/step
# Epoch 159/164
# 28/28 - 0s - loss: 0.0027 - val_loss: 0.1909 - 338ms/epoch - 12ms/step
# Epoch 160/164
# 28/28 - 0s - loss: 0.0016 - val_loss: 0.1131 - 411ms/epoch - 15ms/step
# Epoch 161/164
# 28/28 - 0s - loss: 0.0010 - val_loss: 0.0493 - 407ms/epoch - 15ms/step
# Epoch 162/164
# 28/28 - 0s - loss: 0.0033 - val_loss: 0.0310 - 390ms/epoch - 14ms/step
# Epoch 163/164
# 28/28 - 0s - loss: 0.0025 - val_loss: 0.0723 - 382ms/epoch - 14ms/step
# Epoch 164/164
# 28/28 - 0s - loss: 9.6688e-04 - val_loss: 0.1843 - 346ms/epoch - 12ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 256)               147456
#  al)
# /Users/kendrickwinata/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 163969 (640.50 KB)
# Trainable params: 163969 (640.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 0.42926143103638315

# %%
# %% --------------------------------------- Plot the TRAIN result  -----------------------------------------------------------------
## TRAIN DATA
def plot_traindataset_result(X_train, y_train):


    train_yhat = model.predict(X_train, verbose=0)

    X_scaler = load(open('X_scaler.pkl', 'rb'))
    y_scaler = load(open('y_scaler.pkl', 'rb'))
    train_predict_index = np.load("index_train.npy", allow_pickle=True)

    rescaled_real_y = y_scaler.inverse_transform(y_train)
    rescaled_predicted_y = y_scaler.inverse_transform(train_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=train_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)
    #
    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=train_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    print('real price', real_price)
    print('prediction', predict_result)
    #
    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Training", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    print('-- Train RMSE -- ', RMSE)

    # Calculate MAE
    MAE = mean_absolute_error(real, predicted)
    print('-- MAE -- ', MAE)

    # Calculate R2
    R2 = r2_score(real, predicted)
    print('-- R2 -- ', R2)

    # Calculate MSLE
    MSLE = mean_squared_log_error(real, predicted)
    print('-- MSLE -- ', MSLE)

    # Calculate MAPE
    MAPE = mean_absolute_percentage_error(real, predicted)
    print('-- MAPE -- ', MAPE)

    return predict_result, RMSE, MAE, R2, MSLE, MAPE
    
train_predicted, train_RMSE, train_MAE, train_R2, train_MSLE, train_MAPE  = plot_traindataset_result(X_train, y_train)

train_RMSE = plot_traindataset_result(X_train, y_train)
print("----- Train_RMSE_LSTM -----", train_RMSE)
# Out:
# real price             real_price  real_price  real_price  real_price  real_price  \
# 2013-01-07   22.521044         NaN         NaN         NaN         NaN
# 2013-01-08         NaN   22.171717         NaN         NaN         NaN
# 2013-01-09         NaN         NaN   22.205387         NaN         NaN
# 2013-01-10         NaN         NaN         NaN   22.306396         NaN
# 2013-01-11         NaN         NaN         NaN         NaN   22.601009
# ...                ...         ...         ...         ...         ...
# 2019-12-23         NaN         NaN         NaN         NaN         NaN
# 2019-12-24         NaN         NaN         NaN         NaN         NaN
# 2019-12-26         NaN         NaN         NaN         NaN         NaN
# 2019-12-27         NaN         NaN         NaN         NaN         NaN
# 2019-12-30         NaN         NaN         NaN         NaN         NaN
#
#             real_price  real_price  real_price  real_price  real_price  ...  \
# 2013-01-07         NaN         NaN         NaN         NaN         NaN  ...
# 2013-01-08         NaN         NaN         NaN         NaN         NaN  ...
# 2013-01-09         NaN         NaN         NaN         NaN         NaN  ...
# 2013-01-10         NaN         NaN         NaN         NaN         NaN  ...
# 2013-01-11         NaN         NaN         NaN         NaN         NaN  ...
# ...                ...         ...         ...         ...         ...  ...
# 2019-12-23         NaN         NaN         NaN         NaN         NaN  ...
# 2019-12-24         NaN         NaN         NaN         NaN         NaN  ...
# 2019-12-26         NaN         NaN         NaN         NaN         NaN  ...
# 2019-12-27         NaN         NaN         NaN         NaN         NaN  ...
# 2019-12-30         NaN         NaN         NaN         NaN         NaN  ...
#
#             real_price  real_price  real_price  real_price  real_price  \
# 2013-01-07         NaN         NaN         NaN         NaN         NaN
# 2013-01-08         NaN         NaN         NaN         NaN         NaN
# 2013-01-09         NaN         NaN         NaN         NaN         NaN
# 2013-01-10         NaN         NaN         NaN         NaN         NaN
# 2013-01-11         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2019-12-23         NaN         NaN         NaN         NaN   36.209999
# 2019-12-24         NaN         NaN         NaN         NaN         NaN
# 2019-12-26         NaN         NaN         NaN         NaN         NaN
# 2019-12-27         NaN         NaN         NaN         NaN         NaN
# 2019-12-30         NaN         NaN         NaN         NaN         NaN
#
#             real_price  real_price  real_price  real_price  real_mean
# 2013-01-07         NaN         NaN         NaN         NaN  22.521044
# 2013-01-08         NaN         NaN         NaN         NaN  22.171717
# 2013-01-09         NaN         NaN         NaN         NaN  22.205387
# 2013-01-10         NaN         NaN         NaN         NaN  22.306396
# 2013-01-11         NaN         NaN         NaN         NaN  22.601009
# ...                ...         ...         ...         ...        ...
# 2019-12-23         NaN         NaN         NaN         NaN  36.209999
# 2019-12-24   36.209999         NaN         NaN         NaN  36.209999
# 2019-12-26         NaN       36.25         NaN         NaN  36.250000
# 2019-12-27         NaN         NaN       36.07         NaN  36.070000
# 2019-12-30         NaN         NaN         NaN   35.799999  35.799999
#
# [1752 rows x 1753 columns]
# prediction             predicted_price  predicted_price  predicted_price  \
# 2013-01-07        19.896553              NaN              NaN
# 2013-01-08              NaN        20.501793              NaN
# 2013-01-09              NaN              NaN        19.710085
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10         19.44492              NaN              NaN
# 2013-01-11              NaN        19.721832              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  ...  predicted_price  predicted_price  \
# 2013-01-07              NaN  ...              NaN              NaN
# 2013-01-08              NaN  ...              NaN              NaN
# 2013-01-09              NaN  ...              NaN              NaN
# 2013-01-10              NaN  ...              NaN              NaN
# 2013-01-11              NaN  ...              NaN              NaN
# ...                     ...  ...              ...              ...
# 2019-12-23              NaN  ...              NaN              NaN
# 2019-12-24              NaN  ...              NaN              NaN
# 2019-12-26              NaN  ...              NaN              NaN
# 2019-12-27              NaN  ...              NaN              NaN
# 2019-12-30              NaN  ...              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN        36.290253
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24        36.333935              NaN              NaN
# 2019-12-26              NaN        36.046509              NaN
# 2019-12-27              NaN              NaN        36.307796
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_mean
# 2013-01-07              NaN       19.896553
# 2013-01-08              NaN       20.501793
# 2013-01-09              NaN       19.710085
# 2013-01-10              NaN       19.444920
# 2013-01-11              NaN       19.721832
# ...                     ...             ...
# 2019-12-23              NaN       36.290253
# 2019-12-24              NaN       36.333935
# 2019-12-26              NaN       36.046509
# 2019-12-27              NaN       36.307796
# 2019-12-30        36.149094       36.149094
#
# [1752 rows x 1753 columns]
# -- Train RMSE --  1.8431917257319728
# -- MAE --  1.4407643640422385
# -- R2 --  0.9211672565868441
# -- MSLE --  0.0062400296436853
# -- MAPE --  0.05752255062634473
# real price             real_price  real_price  real_price  real_price  real_price  \
# 2013-01-07   22.521044         NaN         NaN         NaN         NaN
# 2013-01-08         NaN   22.171717         NaN         NaN         NaN
# 2013-01-09         NaN         NaN   22.205387         NaN         NaN
# 2013-01-10         NaN         NaN         NaN   22.306396         NaN
# 2013-01-11         NaN         NaN         NaN         NaN   22.601009
# ...                ...         ...         ...         ...         ...
# 2019-12-23         NaN         NaN         NaN         NaN         NaN
# 2019-12-24         NaN         NaN         NaN         NaN         NaN
# 2019-12-26         NaN         NaN         NaN         NaN         NaN
# 2019-12-27         NaN         NaN         NaN         NaN         NaN
# 2019-12-30         NaN         NaN         NaN         NaN         NaN
#
#             real_price  real_price  real_price  real_price  real_price  ...  \
# 2013-01-07         NaN         NaN         NaN         NaN         NaN  ...
# 2013-01-08         NaN         NaN         NaN         NaN         NaN  ...
# 2013-01-09         NaN         NaN         NaN         NaN         NaN  ...
# 2013-01-10         NaN         NaN         NaN         NaN         NaN  ...
# 2013-01-11         NaN         NaN         NaN         NaN         NaN  ...
# ...                ...         ...         ...         ...         ...  ...
# 2019-12-23         NaN         NaN         NaN         NaN         NaN  ...
# 2019-12-24         NaN         NaN         NaN         NaN         NaN  ...
# 2019-12-26         NaN         NaN         NaN         NaN         NaN  ...
# 2019-12-27         NaN         NaN         NaN         NaN         NaN  ...
# 2019-12-30         NaN         NaN         NaN         NaN         NaN  ...
#
#             real_price  real_price  real_price  real_price  real_price  \
# 2013-01-07         NaN         NaN         NaN         NaN         NaN
# 2013-01-08         NaN         NaN         NaN         NaN         NaN
# 2013-01-09         NaN         NaN         NaN         NaN         NaN
# 2013-01-10         NaN         NaN         NaN         NaN         NaN
# 2013-01-11         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2019-12-23         NaN         NaN         NaN         NaN   36.209999
# 2019-12-24         NaN         NaN         NaN         NaN         NaN
# 2019-12-26         NaN         NaN         NaN         NaN         NaN
# 2019-12-27         NaN         NaN         NaN         NaN         NaN
# 2019-12-30         NaN         NaN         NaN         NaN         NaN
#
#             real_price  real_price  real_price  real_price  real_mean
# 2013-01-07         NaN         NaN         NaN         NaN  22.521044
# 2013-01-08         NaN         NaN         NaN         NaN  22.171717
# 2013-01-09         NaN         NaN         NaN         NaN  22.205387
# 2013-01-10         NaN         NaN         NaN         NaN  22.306396
# 2013-01-11         NaN         NaN         NaN         NaN  22.601009
# ...                ...         ...         ...         ...        ...
# 2019-12-23         NaN         NaN         NaN         NaN  36.209999
# 2019-12-24   36.209999         NaN         NaN         NaN  36.209999
# 2019-12-26         NaN       36.25         NaN         NaN  36.250000
# 2019-12-27         NaN         NaN       36.07         NaN  36.070000
# 2019-12-30         NaN         NaN         NaN   35.799999  35.799999
#
# [1752 rows x 1753 columns]
# prediction             predicted_price  predicted_price  predicted_price  \
# 2013-01-07        19.896553              NaN              NaN
# 2013-01-08              NaN        20.501793              NaN
# 2013-01-09              NaN              NaN        19.710085
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10         19.44492              NaN              NaN
# 2013-01-11              NaN        19.721832              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  ...  predicted_price  predicted_price  \
# 2013-01-07              NaN  ...              NaN              NaN
# 2013-01-08              NaN  ...              NaN              NaN
# 2013-01-09              NaN  ...              NaN              NaN
# 2013-01-10              NaN  ...              NaN              NaN
# 2013-01-11              NaN  ...              NaN              NaN
# ...                     ...  ...              ...              ...
# 2019-12-23              NaN  ...              NaN              NaN
# 2019-12-24              NaN  ...              NaN              NaN
# 2019-12-26              NaN  ...              NaN              NaN
# 2019-12-27              NaN  ...              NaN              NaN
# 2019-12-30              NaN  ...              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN        36.290253
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24        36.333935              NaN              NaN
# 2019-12-26              NaN        36.046509              NaN
# 2019-12-27              NaN              NaN        36.307796
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_mean
# 2013-01-07              NaN       19.896553
# 2013-01-08              NaN       20.501793
# 2013-01-09              NaN       19.710085
# 2013-01-10              NaN       19.444920
# 2013-01-11              NaN       19.721832
# ...                     ...             ...
# 2019-12-23              NaN       36.290253
# 2019-12-24              NaN       36.333935
# 2019-12-26              NaN       36.046509
# 2019-12-27              NaN       36.307796
# 2019-12-30        36.149094       36.149094
#
# [1752 rows x 1753 columns]
# -- Train RMSE --  1.8431917257319728
# -- MAE --  1.4407643640422385
# -- R2 --  0.9211672565868441
# -- MSLE --  0.0062400296436853
# -- MAPE --  0.05752255062634473
# ----- Train_RMSE_LSTM ----- (            predicted_price  predicted_price  predicted_price  \
# 2013-01-07        19.896553              NaN              NaN
# 2013-01-08              NaN        20.501793              NaN
# 2013-01-09              NaN              NaN        19.710085
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10         19.44492              NaN              NaN
# 2013-01-11              NaN        19.721832              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  ...  predicted_price  predicted_price  \
# 2013-01-07              NaN  ...              NaN              NaN
# 2013-01-08              NaN  ...              NaN              NaN
# 2013-01-09              NaN  ...              NaN              NaN
# 2013-01-10              NaN  ...              NaN              NaN
# 2013-01-11              NaN  ...              NaN              NaN
# ...                     ...  ...              ...              ...
# 2019-12-23              NaN  ...              NaN              NaN
# 2019-12-24              NaN  ...              NaN              NaN
# 2019-12-26              NaN  ...              NaN              NaN
# 2019-12-27              NaN  ...              NaN              NaN
# 2019-12-30              NaN  ...              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN        36.290253
# 2019-12-24              NaN              NaN              NaN
# 2019-12-26              NaN              NaN              NaN
# 2019-12-27              NaN              NaN              NaN
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2013-01-07              NaN              NaN              NaN
# 2013-01-08              NaN              NaN              NaN
# 2013-01-09              NaN              NaN              NaN
# 2013-01-10              NaN              NaN              NaN
# 2013-01-11              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2019-12-23              NaN              NaN              NaN
# 2019-12-24        36.333935              NaN              NaN
# 2019-12-26              NaN        36.046509              NaN
# 2019-12-27              NaN              NaN        36.307796
# 2019-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_mean
# 2013-01-07              NaN       19.896553
# 2013-01-08              NaN       20.501793
# 2013-01-09              NaN       19.710085
# 2013-01-10              NaN       19.444920
# 2013-01-11              NaN       19.721832
# ...                     ...             ...
# 2019-12-23              NaN       36.290253
# 2019-12-24              NaN       36.333935
# 2019-12-26              NaN       36.046509
# 2019-12-27              NaN       36.307796
# 2019-12-30        36.149094       36.149094
#
# [1752 rows x 1753 columns], 1.8431917257319728, 1.4407643640422385, 0.9211672565868441, 0.0062400296436853, 0.05752255062634473)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_log_error, mean_absolute_percentage_error

def plot_testdataset_result(X_test, y_test):

    test_yhat = model.predict(X_test, verbose=0)
    y_scaler = load(open('y_scaler.pkl', 'rb'))
    test_predict_index = np.load("index_test.npy", allow_pickle=True)

    rescaled_real_y = y_scaler.inverse_transform(y_test)
    rescaled_predicted_y = y_scaler.inverse_transform(test_yhat)

    # print('reschaled real y', rescaled_real_y)
    # print('rescaled predicted y', rescaled_predicted_y.shape[0])

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=test_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=test_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    print('real price', real_price)
    print('prediction', predict_result)

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Testing", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    print('-- Test RMSE -- ', RMSE)

    # Calculate MAE
    MAE = mean_absolute_error(real, predicted)
    print('-- MAE -- ', MAE)

    # Calculate R2
    R2 = r2_score(real, predicted)
    print('-- R2 -- ', R2)

    # Calculate MSLE
    MSLE = mean_squared_log_error(real, predicted)
    print('-- MSLE -- ', MSLE)

    # Calculate MAPE
    MAPE = mean_absolute_percentage_error(real, predicted)
    print('-- MAPE -- ', MAPE)

    return predict_result, RMSE, MAE, R2, MSLE, MAPE

test_predicted, test_RMSE, test_MAE, test_R2, test_MSLE, test_MAPE = plot_testdataset_result(X_test, y_test)
test_predicted.to_csv("test_predicted_final.csv")
# Out:
# real price             real_price  real_price  real_price  real_price  real_price  \
# 2019-12-31   36.110001         NaN         NaN         NaN         NaN
# 2020-01-02         NaN   36.299999         NaN         NaN         NaN
# 2020-01-03         NaN         NaN   35.959999         NaN         NaN
# 2020-01-06         NaN         NaN         NaN   35.779999         NaN
# 2020-01-07         NaN         NaN         NaN         NaN   35.619999
# ...                ...         ...         ...         ...         ...
# 2022-12-23         NaN         NaN         NaN         NaN         NaN
# 2022-12-27         NaN         NaN         NaN         NaN         NaN
# 2022-12-28         NaN         NaN         NaN         NaN         NaN
# 2022-12-29         NaN         NaN         NaN         NaN         NaN
# 2022-12-30         NaN         NaN         NaN         NaN         NaN
#
#             real_price  real_price  real_price  real_price  real_price  ...  \
# 2019-12-31         NaN         NaN         NaN         NaN         NaN  ...
# 2020-01-02         NaN         NaN         NaN         NaN         NaN  ...
# 2020-01-03         NaN         NaN         NaN         NaN         NaN  ...
# 2020-01-06         NaN         NaN         NaN         NaN         NaN  ...
# 2020-01-07         NaN         NaN         NaN         NaN         NaN  ...
# ...                ...         ...         ...         ...         ...  ...
# 2022-12-23         NaN         NaN         NaN         NaN         NaN  ...
# 2022-12-27         NaN         NaN         NaN         NaN         NaN  ...
# 2022-12-28         NaN         NaN         NaN         NaN         NaN  ...
# 2022-12-29         NaN         NaN         NaN         NaN         NaN  ...
# 2022-12-30         NaN         NaN         NaN         NaN         NaN  ...
#
#             real_price  real_price  real_price  real_price  real_price  \
# 2019-12-31         NaN         NaN         NaN         NaN         NaN
# 2020-01-02         NaN         NaN         NaN         NaN         NaN
# 2020-01-03         NaN         NaN         NaN         NaN         NaN
# 2020-01-06         NaN         NaN         NaN         NaN         NaN
# 2020-01-07         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2022-12-23         NaN         NaN         NaN         NaN   40.169998
# 2022-12-27         NaN         NaN         NaN         NaN         NaN
# 2022-12-28         NaN         NaN         NaN         NaN         NaN
# 2022-12-29         NaN         NaN         NaN         NaN         NaN
# 2022-12-30         NaN         NaN         NaN         NaN         NaN
#
#             real_price  real_price  real_price  real_price  real_mean
# 2019-12-31         NaN         NaN         NaN         NaN  36.110001
# 2020-01-02         NaN         NaN         NaN         NaN  36.299999
# 2020-01-03         NaN         NaN         NaN         NaN  35.959999
# 2020-01-06         NaN         NaN         NaN         NaN  35.779999
# 2020-01-07         NaN         NaN         NaN         NaN  35.619999
# ...                ...         ...         ...         ...        ...
# 2022-12-23         NaN         NaN         NaN         NaN  40.169998
# 2022-12-27   40.080002         NaN         NaN         NaN  40.080002
# 2022-12-28         NaN   39.919998         NaN         NaN  39.919998
# 2022-12-29         NaN         NaN       41.82         NaN  41.820000
# 2022-12-30         NaN         NaN         NaN   41.470001  41.470001
#
# [751 rows x 752 columns]
# prediction             predicted_price  predicted_price  predicted_price  \
# 2019-12-31        36.003181              NaN              NaN
# 2020-01-02              NaN        36.228638              NaN
# 2020-01-03              NaN              NaN        36.358974
# 2020-01-06              NaN              NaN              NaN
# 2020-01-07              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2022-12-23              NaN              NaN              NaN
# 2022-12-27              NaN              NaN              NaN
# 2022-12-28              NaN              NaN              NaN
# 2022-12-29              NaN              NaN              NaN
# 2022-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2019-12-31              NaN              NaN              NaN
# 2020-01-02              NaN              NaN              NaN
# 2020-01-03              NaN              NaN              NaN
# 2020-01-06         35.91008              NaN              NaN
# 2020-01-07              NaN        35.823048              NaN
# ...                     ...              ...              ...
# 2022-12-23              NaN              NaN              NaN
# 2022-12-27              NaN              NaN              NaN
# 2022-12-28              NaN              NaN              NaN
# 2022-12-29              NaN              NaN              NaN
# 2022-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2019-12-31              NaN              NaN              NaN
# 2020-01-02              NaN              NaN              NaN
# 2020-01-03              NaN              NaN              NaN
# 2020-01-06              NaN              NaN              NaN
# 2020-01-07              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2022-12-23              NaN              NaN              NaN
# 2022-12-27              NaN              NaN              NaN
# 2022-12-28              NaN              NaN              NaN
# 2022-12-29              NaN              NaN              NaN
# 2022-12-30              NaN              NaN              NaN
#
#             predicted_price  ...  predicted_price  predicted_price  \
# 2019-12-31              NaN  ...              NaN              NaN
# 2020-01-02              NaN  ...              NaN              NaN
# 2020-01-03              NaN  ...              NaN              NaN
# 2020-01-06              NaN  ...              NaN              NaN
# 2020-01-07              NaN  ...              NaN              NaN
# ...                     ...  ...              ...              ...
# 2022-12-23              NaN  ...              NaN              NaN
# 2022-12-27              NaN  ...              NaN              NaN
# 2022-12-28              NaN  ...              NaN              NaN
# 2022-12-29              NaN  ...              NaN              NaN
# 2022-12-30              NaN  ...              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2019-12-31              NaN              NaN              NaN
# 2020-01-02              NaN              NaN              NaN
# 2020-01-03              NaN              NaN              NaN
# 2020-01-06              NaN              NaN              NaN
# 2020-01-07              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2022-12-23              NaN              NaN        50.915043
# 2022-12-27              NaN              NaN              NaN
# 2022-12-28              NaN              NaN              NaN
# 2022-12-29              NaN              NaN              NaN
# 2022-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2019-12-31              NaN              NaN              NaN
# 2020-01-02              NaN              NaN              NaN
# 2020-01-03              NaN              NaN              NaN
# 2020-01-06              NaN              NaN              NaN
# 2020-01-07              NaN              NaN              NaN
# ...                     ...              ...              ...
# 2022-12-23              NaN              NaN              NaN
# 2022-12-27         50.61845              NaN              NaN
# 2022-12-28              NaN        50.308243              NaN
# 2022-12-29              NaN              NaN          49.8522
# 2022-12-30              NaN              NaN              NaN
#
#             predicted_price  predicted_mean
# 2019-12-31              NaN       36.003181
# 2020-01-02              NaN       36.228638
# 2020-01-03              NaN       36.358974
# 2020-01-06              NaN       35.910080
# 2020-01-07              NaN       35.823048
# ...                     ...             ...
# 2022-12-23              NaN       50.915043
# 2022-12-27              NaN       50.618450
# 2022-12-28              NaN       50.308243
# 2022-12-29              NaN       49.852200
# 2022-12-30        50.506737       50.506737
#
# [751 rows x 752 columns]
# -- Test RMSE --  12.97195478825598
# -- MAE --  11.1320623608626
# -- R2 --  -0.2063918816904693
# -- MSLE --  0.03843756856549754
# -- MAPE --  0.19982130483645885

# %%
test_RMSE
# Out:
# 12.97195478825598
